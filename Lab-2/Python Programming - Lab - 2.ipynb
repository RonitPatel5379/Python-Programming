# %% [markdown]
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 2</b></center>
# <center>Ronit Bhadania
# 24010101017</center>
# <pre>

# %% [markdown]
# ### 01) WAP to print “Hello World..!!”

# %%
print("Hello World..!!")
# Out:
# Hello World..!!

# %% [markdown]
# ### 02) WAP to accept your name and display a welcome message.
# #### Input: Priya
# #### Output: Hello Priya, welcome to Python Lab.

# %%
n = input("Enter your Name:")
print(f"Hello {n},welcome to Python Lab.")
# Out:
# Enter your Name: Ronit
# Hello Ronit,welcome to Python Lab.

# %% [markdown]
# ### 03) WAP to accept three integers and display the numbers, their sum, and average.
# #### Input: 10 20 30
# #### Output:
# ##### Numbers: 10 20 30
# ##### Sum: 60
# ##### Average: 20.0

# %%
a = int(input("Enter first number:"))
b = int(input("Enter second number:"))
c = int(input("Enter third number:"))
sum = a+b+c
Average = sum/3
print(f"Numbers:{a} {b} {c}")
print(f"Sum:{sum}")
print(f"Average:{Average}")
# Out:
# Enter first number: 10
# Enter second number: 20
# Enter third number: 30
# Numbers:10 20 30
# Sum:60
# Average:20.0

# %% [markdown]
# ### 04) WAP to accept name (string), age (int), and percentage (float).
# #### Input : Riya,18,92.5
# #### Output :
# ##### Name: Riya  Type: <class 'str'>
# ##### Age: 18  Type: <class 'int'>
# ##### Percentage: 92.5  Type: <class 'float'>

# %%
Name = input("Enter your name:")
Age = int(input("Enter the age:"))
Percentage = float(input("Enter the percentage"))
print(f"Name:{Name} Type:{type(Name)}")
print(f"Age:{Age} Type:{type(Age)}")
print(f"Percentage:{Percentage} Type:{type(Percentage)}")
# Out:
# Enter your name: Ronit
# Enter the age: 19
# Enter the percentage 88
# Name:Ronit Type:<class 'str'>
# Age:19 Type:<class 'int'>
# Percentage:88.0 Type:<class 'float'>
# Name:Ronit Type:<class 'str'>
# Name:19 Type:<class 'int'>
# Name:87.0 Type:<class 'float'>

# %% [markdown]
# ### 05) WAP to print folowing message using custom separator and end.
# #### Ouutput : Python | Programming | Basics###

# %%
print("Python","Programming","Basics",sep="|",end="###")
# Out:
# Python|Programming|Basics###

# %% [markdown]
# ### 06) WAP to accept a value and display its value, type, and memory id.
# #### Input : hello
# #### Output :
# ##### Value: hello
# ##### Type: <class 'str'>
# ##### ID: 140712345678912

# %%
msg = input("Enter the msg:")
print(f"Value:{msg}")
print(f"Type:{type(msg)}")
print(f"ID:{id(msg)}")
# Out:
# Enter the msg: hello
# Value:hello
# Type:<class 'str'>
# ID:1976593803920

# %% [markdown]
# ### 07) WAP to assign a value to a variable, print id, reassign a new value, and print id again.
# #### Output :
# ##### Original ID of a: 140712345678912
# ##### New ID of a: 140712345678960

# %%
a = int(input("Enter the msg:"))
print(f"Original ID of a:{id(a)}")
a = 20
print(f"New ID of a:{id(a)}")
# Out:
# Enter the msg: 10
# Original ID of a:140706268361928
# New ID of a:140706268362248

# %% [markdown]
# ### 08) WAP to print multiple lines using a single print().
# #### Output:
# ##### Welcome to Python
# ##### This is the second lab
# ##### Enjoy coding!

# %%
print("Welcome to Python\nThis is the second lab\nEnjoy coding!")
# Out:
# Welcome to Python
# This is the second lab
# Enjoy coding!

# %% [markdown]
# ### 09) WAP to display following table of items with proper alignment.
# #### Output :
# | Sr No | Name        | Subject | Grade | Percentage |
# | ----: | ----------- | ------- | :---: | ---------: |
# |     1 | Nisha Patel | Math    |   A   |         92 |
# |     2 | Aarav Modi  | Science |   B+  |         85 |
# |     3 | Jiya Shah   | English |   A+  |         96 |

# %%
print(f"{'Sr No':20} {'Name':20} {'Subject':20} {'Grade':20} {'Percentage':20}")
print(f"{'1':20} {'Nisha Patel':20} {'Math':20} {'A':20} {'92':20}")
print(f"{'2':20} {'Aarav Modi':20} {'Science':20} {'B+':20} {'85':20}")
print(f"{'3':20} {'Jiya Shah':20} {'English':20} {'A+':20} {'96':20}")
# Out:
# Sr No                Name                 Subject              Grade                Percentage
# 1                    Nisha Patel          Math                 A                    92
# 2                    Aarav Modi           Science              B+                   85
# 3                    Jiya Shah            English              A+                   96

# %% [markdown]
# ### 10) WAP to accept a float number and display with 2 decimals, 3 decimals, and width 10.
# #### Input : 37.2567
# #### Output :
# ##### 2 decimals: 37.26
# ##### 3 decimals: 37.257
# ##### Width 10:      37.26

# %%
a = float(input("Enter a number:"))
print(f"2 decimals:{a:.2f}")
print(f"3 decimals:{a:.3f}")
print(f"Width 10:{a:10}")
# Out:
# Enter a number: 37.2567
# 2 decimals:37.26
# 3 decimals:37.257
# Width 10:   37.2567

# %% [markdown]
# ### 11) WAP to accept two integers and display sum, difference, and product using f-strings.
# #### Input : 12 8
# #### Output :
# ##### Sum = 20
# ##### Difference = 4
# ##### Product = 96

# %%
a = int(input("Enter first number:"))
b = int(input("Enter second number:"))
print(f"Sum={a + b}")
print(f"Difference={a - b}")
print(f"Product={a * b}")
# Out:
# Enter first number: 12
# Enter second number: 8
# Sum=20
# Difference=4
# Product=96
# Sum=20
# Difference=4
# Product=96

# %% [markdown]
# ### 12) WAP to accept date in dd mm yyyy format and display in multiple formats.
# #### Input : 01 12 2025
# #### Output :
# ##### 01/12/2025
# ##### 2025-12-01

# %%
date = (input("Enter the date:"))
month = int(input("Enter the month:"))
year = int(input("Enter the year:"))
print(f"{date}",f"{month}",f"{year}",sep="/")
print(f"{year}",f"{month}",f"{date}",sep="-")
# Out:
# Enter the date: 01
# Enter the month: 12
# Enter the year: 2025
# 01/12/2025
# 2025-12-01

# %% [markdown]
# ### 13) WAP to calculate area and perimeter of a circle.

# %%
import math
r = int(input("Enter a number:"))
area = math.pi*r*r
perimeter = 2*math.pi*r
print(f"Area:{area}")
print(f"Perimeter:{perimeter}")
# Out:
# Enter a number: 10
# Area:314.1592653589793
# Perimeter:62.83185307179586

# %% [markdown]
# ### 14) WAP to convert degree into Fahrenheit and vice versa.

# %%
celsius = float(input("Enter temperature in Celsius: "))
fahrenheit = (celsius * 9/5) + 32
print(celsius, "°C is", fahrenheit, "°F")

fahrenheit = float(input("Enter temperature in Fahrenheit: "))
celsius = (fahrenheit - 32) * 5/9
print(fahrenheit, "°F is", celsius, "°C")
# Out:
# Enter temperature in Celsius:  36
# 36.0 °C is 96.8 °F
# Enter temperature in Fahrenheit:  75
# 75.0 °F is 23.88888888888889 °C

# %% [markdown]
# ### 15) WAP to get the distance from user into kilometer, and convert it into meter, feet, inches and centimeter.

# %%
km = float(input("Enter distance in kilometers: "))

meters = km * 1000
feet = km * 3280.84
inches = km * 39370.1
centimeters = km * 100000

print(meters, "Meters")
print(feet, "Feet")
print(inches, "Inches")
print(centimeters, "Centimeters")
# Out:
# Enter distance in kilometers:  1.5
# 1500.0 Meters
# 4921.26 Feet
# 59055.149999999994 Inches
# 150000.0 Centimeters
